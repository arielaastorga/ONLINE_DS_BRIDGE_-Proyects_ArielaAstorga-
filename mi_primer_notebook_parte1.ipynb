# %% [markdown]
# ## Mis primeros pasos con Markdown - Ariela Astorga
#
# ### 1. Párrafos
# # Primer parrafo
# ## Segundo parrafo
# ### Cabecera 3
# #### Cabecera 4
# ##### Cabecera 5

# %%
# Esto es código Python

# %% [markdown]
# ___

# %% [markdown]
# ### 2. Texto HTML

# %% [markdown]
# <h1>Header 1</h1>
# <h2>Header 2</h2>
# <h3>Header 3</h3>

# %% [markdown]
# ### 3. Cambios de formato

# %% [markdown]
# **Texto en negrita**
#
# *Texto en cursiva*
#
# ***Texto en negrita y cursiva***

# %% [markdown]
# ### 3. Hacer una cita

# %% [markdown]
# >hacer una cita

# %% [markdown]
# ### 4. Saltos de linea

# %% [markdown]
# "En un lugar de la mancha"  "Veinte anos despues"

# %% [markdown]
# ### 5. Listas ordenadas

# %% [markdown]
# 1. Lista uno
# 2. Lista dos
# 3. Lista tres

# %% [markdown]
# ### 6. Introducir codigo Phyton

# %% [markdown]
# ```codigo Python
# variable ="esto es una variable"

# %% [markdown]
# ### 7. Líneas de separación

# %% [markdown]
# ___

# %% [markdown]
# ## 8. Enlaces varios

# %% [markdown]
# [enlace a Google] (http://www.google.es)
# [enlace al documento] (### 3.-Hacer-una-cita)

# %% [markdown]
# ## 9. Imagenes

# %% [markdown]
# ![está en el mismo directorio](./gato.png)

# %% [markdown]
# Prueba agrandar imagen

# %% [markdown]
# <img src="./img/gato.png" width = 50>
