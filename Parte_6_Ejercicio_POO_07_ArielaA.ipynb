# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:

    electrodomesticos = list()
    Abierta = True
   
    def __init__(self, nombre, direccion, num_empleados, ventas):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas = ventas

    def print_datos(self):
        print("Nombre:", self.nombre)
        print("Direccion:", self.direccion)
        print("Numero de empleados:", self.num_empleados)
        print("Ventas:", self.ventas)        


    # Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
    def calcular_ventas(self, nombre, ventas):
        for nombre in self.nombre:
            total_ventas = sum(ventas)

            print(total_ventas)
            return total_ventas
            
        return None
    
    # Método que calcula la media de ventas de los ultimos meses, por empleado    
    def media_vtasxempleado(self, nombre, ventas, num_empleados):
        for nombre in self.nombre:
            media_ventas = (sum(ventas))/num_empleados

            print(media_ventas)
            return media_ventas
            
        return None
    
    # Método que devuelve en un string el nombre de la tienda, junto con su dirección.  
    def caracteristicas(self):
         
        print("La tienda de nombre " + self.nombre + ", esta ubicada en " + self.direccion)
        return self.nombre + self.direccion
        
    # Método que obtiene las ventas del último mes
    def venta_ultimomes(self, nombre, ventas):
        for nombre in self.nombre:
            ultima_venta = ventas[-1]

            
            return ultima_venta
            
        return None
    
    
    # Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. 
    #Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), 
    #si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, 
    #y además devuelve las ventas con el aumento.   
    
    def proy_ventas(self, nombre, ventas, x):
       if x < 1000:           
           factor = 1.2
           ventas_futuras = [y * factor for y in ventas]
       if x >= 1000:
           factor = 1.5
           ventas_futuras = [y * factor for y in ventas]

       ventas = ventas_futuras
       print(ventas_futuras, "invirtiendo un total en marketing de",x)
       return None
   


    # Atrbuto para verificar Avenida
    def dir_avenida(self, nombre, direccion):
      dire =  self.direccion
      lista_dir = dire.split()

      for palabra in lista_dir:
          if palabra == "Avenida":
              print(self.nombre)
            
        
      return None

# %%
# 1._Creamos tres tiendas
tienda1 = Tienda("Madrid","Calle de Teruel",35,[4,5,6])
tienda2 = Tienda("Sevilla","Calle de Antonio Salado",30,[6,7,8])
tienda3 = Tienda("Valencia","Avenida Grande",33,[9,10,11])

# 2._Comprobando el programa enterior para la tienda de Madrid
print("Comprobando el programa enterior para la tienda de",tienda1.nombre)
print("Calculamos las ventas de",tienda1.nombre)
tienda1.calcular_ventas("Madrid",[4,5,6])
print("")
print("Calculamos la media de ventas de los ultimos meses, por empleado de la tienda de",tienda1.nombre)
tienda1.media_vtasxempleado("Madrid",[4,5,6],3)
print("")
print("Imprimimos las caracteristicas de la empresa")
tienda1.caracteristicas()
print("")
print("Las ventas del ultimo mes son en la tienda de", tienda1.nombre, "son", tienda1.venta_ultimomes("Madrid",[4,5,6]))


print("")
print("Las ventas futuras dada la inversion en marketing, en la tienda de",tienda1.nombre , "son")
tienda1.proy_ventas("Madrid",[4,5,6],900)
print("")

#3._Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle for

print("Las ventas del ultimo mes en la tienda de", tienda1.nombre, "es", tienda1.venta_ultimomes("Madrid",[4,5,6]))
print("Las ventas del ultimo mes en la tienda de", tienda2.nombre, "es", tienda2.venta_ultimomes("Sevilla",[6,7,8]))
print("Las ventas del ultimo mes en la tienda de", tienda3.nombre, "es", tienda3.venta_ultimomes("Valencia",[9,10,11]))
# Out:
# Comprobando el programa enterior para la tienda de Madrid
# Calculamos las ventas de Madrid
# 15
#
# Calculamos la media de ventas de los ultimos meses, por empleado de la tienda de Madrid
# 5.0
#
# Imprimimos las caracteristicas de la empresa
# La tienda de nombre Madrid, esta ubicada en Calle de Teruel
#
# Las ventas del ultimo mes son en la tienda de Madrid son 6
#
# Las ventas futuras dada la inversion en marketing, en la tienda de Madrid son
# [4.8, 6.0, 7.199999999999999] invirtiendo un total en marketing de 900
#
# Las ventas del ultimo mes en la tienda de Madrid es 6
# Las ventas del ultimo mes en la tienda de Sevilla es 8
# Las ventas del ultimo mes en la tienda de Valencia es 11

# %%
#4._Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"

print("Las tiendas que estan ubicadas en una Avenida son")

tienda1.dir_avenida("Madrid","Calle de Teruel")
tienda2.dir_avenida("Sevilla","Calle de Antonio Salado")
tienda3.dir_avenida("Valencia","Avenida Grande")
        

#5._Seguro que ya has hecho este apartado... Documenta la clase :)
# Out:
# Las tiendas que estan ubicadas en una Avenida son
# Valencia

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
# Implementa la clase Perro
class Perro:
    patas = 4
    orejas = 2
    ojos = 2
    velocidad  = 0
    pelo = "marron"
    dueno = "NO"

    # Constructor de raza del perro
    def __init__(self, raza):
        self.raza = raza
      
    # metodo andar    
    def andar(self, velocidad, aumento_velocidad):
        velocidad = velocidad + aumento_velocidad

        print("La nueva velocidad del perro es", velocidad)
        return None

    # metodo parar    
    def parar(self, velocidad):
        velocidad = 0

        print("El perro esta detenido")
        return None

    # metodo ladrar
    
    def ladrar(self, entrada):
        print("GUAU!" + string(entrada))
        return None

# %%
# Crea un objeto de tipo Perro, sin dueño
mi_perro = Perro(raza = "chihuahua")

# Comprueba que están bien todos sus atributos
print("La raza del perro es", mi_perro.raza)
print("El perro", mi_perro.dueno,"tiene dueno")
print("El perro tiene", mi_perro.patas,"patas")
print("El perro tiene", mi_perro.ojos,"ojos")
print("El perro tiene el pelo color", mi_perro.pelo)
print("La velocidad del perro es", mi_perro.velocidad)

# Prueba que ande, y comprueba su velocidad
mi_perro.andar(0, 10)

# Páralo
mi_perro.parar(10)

# Documenta la clase Perro
# Out:
# La raza del perro es chihuahua
# El perro NO tiene dueno
# El perro tiene 4 patas
# El perro tiene 2 ojos
# El perro tiene el pelo color marron
# La velocidad del perro es 0
# La nueva velocidad del perro es 10
# El perro esta detenido
