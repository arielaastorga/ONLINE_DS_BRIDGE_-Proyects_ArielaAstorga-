# %% [markdown]
# ### Fuentes de datos

# %% [markdown]
# 1. Energía abierta.cl
#
# Página web: http://energiaabierta.cl/categorias-estadistica/electricidad/?_sf_s=costo
#
# Se descargan los precios eléctricos marginales por barra, por hora y por mes.
# Se encuentran listados en csv por mes.

# %% [markdown]
# 2.  National solar radiation data base
#
# Página web: https://nsrdb.nlr.gov/data-viewer
#
# Se descargan datos meteorológicos y de medición de radiación. En la memoria se puede ver un detalle de las variables obtenidas.
